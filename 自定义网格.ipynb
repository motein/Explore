# %% [markdown]
# #### 参考
# 1. [Using ax.vlines and ax.hlines](https://scipython.com/book/chapter-7-matplotlib/examples/using-axvlines-and-axhlines/)
# 2. [matplotlib.axes.Axes.vlines() in Python](https://www.geeksforgeeks.org/matplotlib-axes-axes-vlines-in-python/)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)
ax.scatter(x, y, c=colors, s=sizes, alpha=0.3,cmap='viridis')

vx = list(np.linspace(-3,3,8))
hx = list(np.linspace(-3,3,8))

ax.vlines(vx, -3, 3, lw=0.5, linestyles ="dotted", color='grey', alpha=0.5)
ax.hlines(hx, -1, 3, lw=0.5, linestyles ="dotted", color='grey', alpha=0.5)

plt.show()

# %%
np.sqrt(0.5)
# Out:
# 0.7071067811865476

# %%
0.7071067811865476**2
# Out:
# 0.5000000000000001

# %%
a = [1,3,2,5,4]
a.sort()

# %%
a
# Out:
# [1, 2, 3, 4, 5]
